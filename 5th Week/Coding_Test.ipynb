# %% [markdown]
# # Q1. 100이하의 자연수에서 3의 배수 또는 5의 배수이지만 15의 배수는 아닌 값을 아래 정답처럼 출력하기

# %% [markdown]
# ```python
# # 정답
# 3 5 6 9 10 12 18 20 21 24 25 27 33 35 36 39 40 42 48 50 51 54 55 57 63 65 66 69 70 72 78 80 81 84 85 87 93 95 96 99 100
# ```

# %%
# 코드작성

# %% [markdown]
# # Q2. 100이하의 자연수에서 소수를 추출한 뒤 1의 자리 숫자가 3인 숫자는 제외하고 아래 정답처럼 출력하기

# %% [markdown]
# ```python
# # 정답
# 2 5 7 11 17 19 29 31 37 41 47 59 61 67 71 79 89 97
# ```

# %%
# 코드작성

# %% [markdown]
# # Q3. 1000 이하의 자연수 중에서 2와 6이 총 몇번 나오는지 카운팅하여 아래 정답처럼 출력하기

# %% [markdown]
# ```python
# # 예를 들어 226은 3, 206은 2로 카운팅해야한다
#
# # 정답
# 600
# ```

# %%
# 코드작성

# %% [markdown]
# # Q4. 양의 정수가 입력되면 입력된 숫자만큼의 층을 가진 피라미드를 아래의 정답처럼 출력하기

# %% [markdown]
# > **조건** <br>
# 입력은 양의 정수로 한정 <br>
# 입력된 숫자가 홀수면 거꾸로 된 피라미드 출력, <br>
# 짝수면 정상적인 피라미드 출력 <br>
# 홀수 층에는 '+', 짝수 층에는 '*'로 표시 (맨 밑이 1층) <br>
# 함수로 만드시오
#
# ```python
# # 정답
# pyramid(7)
# +++++++++++++
#  ***********
#   +++++++++
#    *******
#     +++++
#      ***
#       +
#
# pyramid(4)
#     *
#    +++
#   *****
#  +++++++
# ```

# %%
# 코드 작성

# %% [markdown]
# # Q5. 아래 num_list 요소들의 절댓값으로 오름차순 정렬하여 정답처럼 출력하기  (파이썬 내장 함수 사용 없이 반복문 사용)

# %% [markdown]
# ```python
# num_list = [5, 19, 2, -6, 0.3]
#
# # 정답
# [0.3, 2, 5, -6, 19]
# ```

# %%
# 코드작성

# %% [markdown]
# # Q6. 리스트에 추가 및 제거

# %% [markdown]
# ## 06-1. 입력값이 num_list(리스트)에 존재하면 리스트 안의 값을 제거하고 없으면 추가하고 변경된 num_list를 아래 정답처럼 출력하는 modify_list 함수 만들기

# %% [markdown]
# ```python
# num_list = [1, 2, 6, 7, 43, 89, 4, 10]
#
# # 정답
# modify_list(2)
# [1, 6, 7, 43, 89, 4, 10]
#
# modify_list(9)
# [1, 6, 7, 43, 89, 4, 10, 9]
# ```

# %%
num_list = [1, 2, 6, 7, 43, 89, 4, 10]

# 코드 작성

# %% [markdown]
# ## 06-2. 아래 두 리스트 a_list, b_list를 합친 후 합쳐진 리스트 값을 아래 정답처럼 출력하는 merge_list 함수 만들기

# %% [markdown]
# ```python
#     # 정답
#     merge_list(a_list, b_list)
#     ['a', 1, 87, 9, 't', '55', 'c', 56, 3]
# ```

# %%
a_list = ['a', 1, 87, 9, 't']
b_list = ['55', 'c', 56, 3]


def merge_list():
    # 코드작성

# %% [markdown]
# # Q7. 딕셔너리 추가, 제거 및 추출

# %% [markdown]
# ## 07-1. 입력된 temp_dict(딕셔너리)의 키값이 age_dict의 키 값에 존재하면 딕셔너리 안의 {키:값} 쌍을 제거하고 없으면 추가하고 아래 정답처럼 출력하는 modify_dict 함수 만들기

# %% [markdown]
# ```python
#     # 정답
#     modify_dict({'Tom': 51})
#     {'Jason': 22, 'David': 28, 'Jenny': 30}
#
#     modify_dict({'Ry': 42})
#     {'Jason': 22, 'David': 28, 'Jenny': 30, 'Ry': 42}
#
# ```

# %%
age_dict = {
    'Tom': 32,
    'Jason': 22,
    'David': 28,
    'Jenny': 30
}

def modify_dict(temp_dict):
    # 코드작성

# %% [markdown]
# ## 07-2. 아래의 딕셔너리에서 원하는 값 추출

# %%
drama_dict = {
    'info_01': {
        '제목': '악마판사',
        '시청연령': '15세이상',
        '방영시간': None,
        '방영상태': '방영진행중',
    },
    'info_02': {
        '제목': '아모르 파티 - 사랑하라, 지금',
        '시청연령': '15세이상',
        '방영시간': '2021.04.12. ~ (월~금) 오전 08:35',
        '방영상태': '방영진행중',
    },
    'info_03': {
        '제목': '나를 사랑한 스파이',
        '시청연령': '15세이상',
        '방영시간': '2020.10.21. ~ 2020.12.17.',
        '방영상태': '방영종료',
    },
    'info_04': {
        '제목': '어느 날 우리 집 현관으로 멸망이 들어왔다',
        '시청연령': '15세이상',
        '방영시간': '2021.05.10. ~ 2021.06.29.',
        '방영상태': '방영종료',
    },
    'info_05': {
        '제목': '디어엠(Dear.M)',
        '시청연령': '15세이상',
        '방영시간': None,
        '방영상태': '방영예정',
    },
    'info_06': {
        '제목': '밥이 되어라',
        '시청연령': '15세이상',
        '방영시간': '2021.01.11. ~ 2021.07.02.',
        '방영상태': '방영종료',
    }
}

# %% [markdown]
# ## 07-2-1. 위의 drama_dict에서 방영상태가 '방영진행중'인 경우 '방영중'으로 바꾸는 change_status 함수 만들기 (drama_dict를 출력하는 함수가 아니라 아래 정답처럼 실행되어야 한다)

# %% [markdown]
# ```python
#     # 정답
#     change_status()
#     drama_dict
#     {'info_01': {'방영상태': '방영중', '방영시간': None, '시청연령': '15세이상', '제목': '악마판사'},
#     'info_02': {'방영상태': '방영중',
#     '방영시간': '2021.04.12. ~ (월~금) 오전 08:35',
#     '시청연령': '15세이상',
#     '제목': '아모르 파티 - 사랑하라, 지금'},
#     'info_03': {'방영상태': '방영종료',
#     '방영시간': '2020.10.21. ~ 2020.12.17.',
#     '시청연령': '15세이상',
#     '제목': '나를 사랑한 스파이'},
#     'info_04': {'방영상태': '방영종료',
#     '방영시간': '2021.05.10. ~ 2021.06.29.',
#     '시청연령': '15세이상',
#     '제목': '어느 날 우리 집 현관으로 멸망이 들어왔다'},
#     'info_05': {'방영상태': '방영예정',
#     '방영시간': None,
#     '시청연령': '15세이상',
#     '제목': '디어엠(Dear.M)'},
#     'info_06': {'방영상태': '방영종료',
#     '방영시간': '2021.01.11. ~ 2021.07.02.',
#     '시청연령': '15세이상',
#     '제목': '밥이 되어라'}}
# ```

# %%
def change_status():
    # 코드작성

# %% [markdown]
# ## 07-2-2. 위의 drama_dict에서 방영상태가 '방영종료'인 딕셔너리를 아래 정답처럼 출력하는 end_drama 함수 만들기

# %% [markdown]
# ```python
#     # 정답
#     end_drama()
#     {'제목': '나를 사랑한 스파이', '시청연령': '15세이상', '방영시간': '2020.10.21. ~ 2020.12.17.', '방영상태': '방영종료'}
#     {'제목': '어느 날 우리 집 현관으로 멸망이 들어왔다', '시청연령': '15세이상', '방영시간': '2021.05.10. ~ 2021.06.29.', '방영상태': '방영종료'}
#     {'제목': '밥이 되어라', '시청연령': '15세이상', '방영시간': '2021.01.11. ~ 2021.07.02.', '방영상태': '방영종료'}
# ```

# %%
def end_drama():
    # 코드작성

# %% [markdown]
# # Q8. 달팽이 문제

# %% [markdown]
# > 땅 위에 달팽이가 있고 높이가 h미터인 나무 막대에 올라가려고 한다. <br>
# 낮에는 x미터만큼 올라가고 밤에는 y미터만큼 떨어진다.<br>
# x만큼 올라간 후 또는 y만큼 떨어진 후의 남은 길이가 정확히 h/2 되면 마법의 문을 통해 곧바로 h의 3/4 지점으로 이동한다.<br>
# 정상에 올라간 후에는 밤에 떨어지지 않는다.<br>
# 달팽이가 나무 막대에 올라가려면 총 몇일이 걸리는지 구하는 snail 함수를 만드시오.<br>
# (x와 y는 1이상의 졍수이고 y < x 를 만족한다. h를 나눴을 때 나머지는 모두 버린다.)
#
# ```python
# # 정답
# snail(5, 3, 10)
# 3
# snail(4, 2, 20)
# 7
# ```

# %%
def snail(x, y, h):
    # 코드작성
