# %% [markdown]
# ## 1.데이터 불러오기

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# ### 1-1 그래프에 한글 폰트 적용하기 (colab에서 적용하기)
# 명령어 실행 후 런타임 다시 시작

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 2s (5,383 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160837 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd
import urllib.request
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
# 데이터 출처 : https://github.com/bab2min/corpus/tree/master/sentiment

urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/naver_shopping.txt",
     filename="ratings_total.txt"
)
# Out:
# ('ratings_total.txt', <http.client.HTTPMessage at 0x7f1b00dd8c90>)

# %%
# !ls
# Out:
# gdrive	ratings_total.txt  sample_data

# %%
naver_review_df = pd.read_table('ratings_total.txt')
naver_review_df
# Out:
#         5                                            배공빠르고 굿
# 0       2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 1       5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 2       2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 3       5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# 4       2  비추합니다 계란 뒤집을 때 완전 불편해요 ㅠㅠ 코팅도 묻어나고 보기엔 예쁘고 실용적...
# ...    ..                                                ...
# 199994  2                                    장마라그런가!!! 달지않아요
# 199995  5  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199996  5                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199997  5                                      넘이쁘고 쎄련되보이네요~
# 199998  5   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [199999 rows x 2 columns]

# %% [markdown]
# ### column 설정하여 데이터 불러오기

# %%
naver_review_df = pd.read_table('ratings_total.txt', names=['ratings', 'reviews'])
naver_review_df
# Out:
#         ratings                                            reviews
# 0             5                                            배공빠르고 굿
# 1             2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2             5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3             2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4             5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# ...         ...                                                ...
# 199995        2                                    장마라그런가!!! 달지않아요
# 199996        5  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199997        5                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199998        5                                      넘이쁘고 쎄련되보이네요~
# 199999        5   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [200000 rows x 2 columns]

# %%
naver_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ratings  200000 non-null  int64
#  1   reviews  200000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 3.1+ MB

# %% [markdown]
# ## 2.데이터 파악 및 전처리

# %% [markdown]
# ### 2-1.긍부정 라벨 부여

# %%
naver_review_df['ratings'].unique()
# Out:
# array([5, 2, 1, 4])

# %% [markdown]
# ### 리뷰 점수가 1, 2점인 경우 0으로 4, 5점인 경우 1로 변환
# ### 부정적인 리뷰 = 0, 긍정적인 리뷰 = 1

# %%
naver_review_df['ratings'].replace([1, 2, 4, 5], [0, 0, 1, 1], inplace=True)
naver_review_df
# Out:
#         ratings                                            reviews
# 0             1                                            배공빠르고 굿
# 1             0                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2             1  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3             0  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4             1                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# ...         ...                                                ...
# 199995        0                                    장마라그런가!!! 달지않아요
# 199996        1  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199997        1                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199998        1                                      넘이쁘고 쎄련되보이네요~
# 199999        1   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [200000 rows x 2 columns]

# %% [markdown]
# ### 2-2.중복제거

# %%
naver_review_df[naver_review_df.duplicated()].sort_values(by='reviews')
# Out:
#         ratings                     reviews
# 10958         1                 2022년까지 넉넉함
# 137154        0           3년 동안 꾸준히 쓰는데 좋아요
# 155806        1             가격에 비해 가성비 좋습니다
# 172758        0                 가나다라마바사아자차카
# 118540        0                  감사합니다 잘쓸께요
# ...         ...                         ...
# 197220        0          정사이즈보다 조금더 크게시켜야할듯
# 195204        0              제품이 그냥 그냥 그래요~
# 73979         1             좋아보이네요~잘써보겠습니다~
# 177221        0                  크기가 너무 작아요
# 184478        0  한사이즈 크게 주문하세요 스판기 없고 통풍 안됨
#
# [82 rows x 2 columns]

# %%
naver_review_df[naver_review_df.duplicated(subset=['reviews'])].sort_values(by='reviews')
# Out:
#         ratings                     reviews
# 10958         1                 2022년까지 넉넉함
# 137154        0           3년 동안 꾸준히 쓰는데 좋아요
# 155806        1             가격에 비해 가성비 좋습니다
# 172758        0                 가나다라마바사아자차카
# 118540        0                  감사합니다 잘쓸께요
# ...         ...                         ...
# 73979         1             좋아보이네요~잘써보겠습니다~
# 141349        1                      크고 좋아요
# 177221        0                  크기가 너무 작아요
# 184478        0  한사이즈 크게 주문하세요 스판기 없고 통풍 안됨
# 195539        1               효과가 있는지 모르겠어요
#
# [92 rows x 2 columns]

# %% [markdown]
# ### reviews를 기준으로 중복 검사를 한 결과와 ratings, reviews를 기준으로 중복 검사를 한 결과가 다르다?!

# %%
review_standard = list(naver_review_df[naver_review_df.duplicated(subset=['reviews'])].index)
total_standard = list(naver_review_df[naver_review_df.duplicated()].index) 
except_list = []

for idx in review_standard:
    if idx not in total_standard:
        except_list.append(idx)

# %%
except_list
# Out:
# [63566, 77799, 84519, 85120, 111543, 141349, 163277, 164740, 195539, 196291]

# %%
naver_review_df.iloc[except_list[0]]
# Out:
# ratings                0
# reviews    아직 잘 모르겠어요...
# Name: 63566, dtype: object

# %%
naver_review_df.query('reviews == "아직 잘 모르겠어요..."')
# Out:
#        ratings        reviews
# 31363        1  아직 잘 모르겠어요...
# 63566        0  아직 잘 모르겠어요...

# %% [markdown]
# ### reviews는 같지만 ratings이 다른 경우가 있다! 제거하기!

# %%
delete_idx = []

for idx in except_list:
    duplicated_review = naver_review_df.iloc[idx]['reviews']
    delete_idx.extend(list(naver_review_df.query(f'reviews == "{duplicated_review}"').index))

# %%
delete_idx
# Out:
# [31363,
#  63566,
#  33598,
#  77799,
#  31569,
#  84519,
#  22365,
#  85120,
#  77089,
#  111543,
#  17575,
#  141349,
#  46871,
#  163277,
#  110232,
#  164740,
#  31088,
#  195539,
#  172462,
#  196291]

# %%
naver_review_df.drop(delete_idx, inplace=True)
naver_review_df.reset_index(drop=True, inplace=True)
naver_review_df
# Out:
#         ratings                                            reviews
# 0             1                                            배공빠르고 굿
# 1             0                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2             1  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3             0  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4             1                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# ...         ...                                                ...
# 199975        0                                    장마라그런가!!! 달지않아요
# 199976        1  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199977        1                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199978        1                                      넘이쁘고 쎄련되보이네요~
# 199979        1   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [199980 rows x 2 columns]

# %% [markdown]
# ### 이제 ratings, reviews를 기준으로 중복이 있는 행을 제거하자

# %%
naver_review_df.drop_duplicates(inplace=True, ignore_index=True)
naver_review_df
# Out:
#         ratings                                            reviews
# 0             1                                            배공빠르고 굿
# 1             0                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2             1  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3             0  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4             1                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# ...         ...                                                ...
# 199893        0                                    장마라그런가!!! 달지않아요
# 199894        1  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199895        1                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199896        1                                      넘이쁘고 쎄련되보이네요~
# 199897        1   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [199898 rows x 2 columns]

# %% [markdown]
# ## 4.명사로 토큰화

# %%
# 한국어 토큰화 라이브러리 설치

# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 121 kB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.5 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 57.3 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
from konlpy.tag import Okt
from tqdm import tqdm
import pickle

# %%
okt = Okt()
tokenized_noun = []

for review in tqdm(naver_review_df['reviews']):
    tokenized = okt.nouns(review)
    tokenized_noun.append(" ".join(tokenized))
# Out:
# 100%|██████████| 199898/199898 [08:06<00:00, 410.53it/s]

# %%
with open('/content/gdrive/MyDrive/Ulsan_univ/dohee/shared/배포자료_리뷰분류/data/naver_noun.pkl', 'rb') as f:
    tokenized_noun = pickle.load(f)

# %%
tokenized_df = pd.DataFrame(data={'reviews': tokenized_noun, 'ratings': naver_review_df['ratings']})
tokenized_df.reset_index(drop=True, inplace=True)
tokenized_df
# Out:
#                                                   reviews  ratings
# 0                                                    배공 굿        1
# 1                                         택배 엉망 용 집 밑 층 말        0
# 2                    아주 바지 정말 개 더 구매 가격 대박 바느질 조금 가성 비 최고        1
# 3       선물 용 전달 상품 머그컵 당황 바로 배송 누락 확인 안 바로 선물 큰일 날 배송 ...        0
# 4                                   민트 색상 옆 손잡이 거 용 도로 사용        1
# ...                                                   ...      ...
# 199893                                            장마 런가 달        0
# 199894  다이슨 케이스 구매 다이슨 슈퍼소닉 드라이기 케이스 구매 가격 배송 파 다이슨 슈퍼...        1
# 199895                                          로드샾 세배 자주        1
# 199896                                                           1
# 199897                                     사용 다른 제품 본적 배송        1
#
# [199898 rows x 2 columns]

# %% [markdown]
# ### 중복제거

# %%
tokenized_df[tokenized_df.duplicated()]
# Out:
#        reviews  ratings
# 104                   1
# 126                   1
# 147         배송        1
# 179                   1
# 182         배송        1
# ...        ...      ...
# 199882      품질        1
# 199883   별로 진짜        0
# 199886       양        1
# 199890      선물        1
# 199896                1
#
# [31969 rows x 2 columns]

# %%
tokenized_df[tokenized_df.duplicated(subset=['reviews'])]
# Out:
#        reviews  ratings
# 104                   1
# 126                   1
# 147         배송        1
# 179                   1
# 182         배송        1
# ...        ...      ...
# 199882      품질        1
# 199883   별로 진짜        0
# 199886       양        1
# 199890      선물        1
# 199896                1
#
# [33936 rows x 2 columns]

# %%
tokenized_df.drop_duplicates(subset=['reviews'], inplace=True, ignore_index=True)
tokenized_df
# Out:
#                                                   reviews  ratings
# 0                                                    배공 굿        1
# 1                                         택배 엉망 용 집 밑 층 말        0
# 2                    아주 바지 정말 개 더 구매 가격 대박 바느질 조금 가성 비 최고        1
# 3       선물 용 전달 상품 머그컵 당황 바로 배송 누락 확인 안 바로 선물 큰일 날 배송 ...        0
# 4                                   민트 색상 옆 손잡이 거 용 도로 사용        1
# ...                                                   ...      ...
# 165957  전반 어플 각종 서비스 완성 도 서버 다운 서버 다운 그냥 콘센트 회사 스마트 컨 ...        1
# 165958                                            장마 런가 달        0
# 165959  다이슨 케이스 구매 다이슨 슈퍼소닉 드라이기 케이스 구매 가격 배송 파 다이슨 슈퍼...        1
# 165960                                          로드샾 세배 자주        1
# 165961                                     사용 다른 제품 본적 배송        1
#
# [165962 rows x 2 columns]

# %% [markdown]
# ### 비어있는 review 제거

# %%
tokenized_df.query('reviews == ""')
# Out:
#    reviews  ratings
# 67                1

# %%
empty_index = list(tokenized_df.query('reviews == ""').index)
tokenized_df.drop(empty_index, inplace=True)
tokenized_df.reset_index(drop=True, inplace=True)
tokenized_df
# Out:
#                                                   reviews  ratings
# 0                                                    배공 굿        1
# 1                                         택배 엉망 용 집 밑 층 말        0
# 2                    아주 바지 정말 개 더 구매 가격 대박 바느질 조금 가성 비 최고        1
# 3       선물 용 전달 상품 머그컵 당황 바로 배송 누락 확인 안 바로 선물 큰일 날 배송 ...        0
# 4                                   민트 색상 옆 손잡이 거 용 도로 사용        1
# ...                                                   ...      ...
# 165956  전반 어플 각종 서비스 완성 도 서버 다운 서버 다운 그냥 콘센트 회사 스마트 컨 ...        1
# 165957                                            장마 런가 달        0
# 165958  다이슨 케이스 구매 다이슨 슈퍼소닉 드라이기 케이스 구매 가격 배송 파 다이슨 슈퍼...        1
# 165959                                          로드샾 세배 자주        1
# 165960                                     사용 다른 제품 본적 배송        1
#
# [165961 rows x 2 columns]

# %%
tokenized_df['reviews'].apply(lambda x: len(x.split())).value_counts().sort_index().plot(kind='bar', figsize=(12, 6));
tokenized_df['reviews'].apply(lambda x: len(x.split())).describe()
# Out:
# count    165961.000000
# mean          6.752333
# std           4.805919
# min           1.000000
# 25%           3.000000
# 50%           5.000000
# 75%           9.000000
# max          41.000000
# Name: reviews, dtype: float64

# %% [markdown]
# 토큰화된 데이터 저장

# %%
# import pickle

# path = ''

# with open(path+'/tokenized_naver_review.pkl', 'wb') as f:
#     pickle.dump(tokenized_df, f)

# %% [markdown]
# ## 5.단어 정수 인코딩

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
MAX_NUM_WORD = 2000
MAX_WORD_LENGTH = 9

# %%
tokenizer = Tokenizer(MAX_NUM_WORD)
tokenizer.fit_on_texts(tokenized_df['reviews'])
len(tokenizer.word_index)
# Out:
# 35829

# %% [markdown]
# 해당 인덱스의 단어가 몇 번 등장하는지 확인

# %%
tokenizer.word_counts[tokenizer.index_word[2000]]
# Out:
# 71

# %%
tokenizer.word_index
# Out:
# {'배송': 1,
#  '구매': 2,
#  '사용': 3,
#  '제품': 4,
#  '그냥': 5,
#  '가격': 6,
#  '좀': 7,
#  '생각': 8,
#  '주문': 9,
#  '맛': 10,
#  '더': 11,
#  '때': 12,
#  '것': 13,
#  '별로': 14,
#  '사이즈': 15,
#  '개': 16,
#  '포장': 17,
#  '거': 18,
#  '상품': 19,
#  '부분': 20,
#  '요': 21,
#  '냄새': 22,
#  '정말': 23,
#  '하나': 24,
#  '안': 25,
#  '진짜': 26,
#  '구입': 27,
#  '조금': 28,
#  '반품': 29,
#  '아주': 30,
#  '또': 31,
#  '느낌': 32,
#  '정도': 33,
#  '아이': 34,
#  '제': 35,
#  '맘': 36,
#  '완전': 37,
#  '용': 38,
#  '처음': 39,
#  '저': 40,
#  '다시': 41,
#  '사진': 42,
#  '디자인': 43,
#  '비': 44,
#  '상태': 45,
#  '보고': 46,
#  '한번': 47,
#  '효과': 48,
#  '다른': 49,
#  '추천': 50,
#  '걸': 51,
#  '이': 52,
#  '향': 53,
#  '크기': 54,
#  '선물': 55,
#  '교환': 56,
#  '색상': 57,
#  '대비': 58,
#  '해': 59,
#  '계속': 60,
#  '전': 61,
#  '물건': 62,
#  '바로': 63,
#  '번': 64,
#  '마음': 65,
#  '다음': 66,
#  '집': 67,
#  '박스': 68,
#  '듯': 69,
#  '수': 70,
#  '실망': 71,
#  '돈': 72,
#  '가성': 73,
#  '설치': 74,
#  '곳': 75,
#  '후': 76,
#  '택배': 77,
#  '색': 78,
#  '아기': 79,
#  '이번': 80,
#  '만족': 81,
#  '불량': 82,
#  '조립': 83,
#  '옷': 84,
#  '물': 85,
#  '못': 86,
#  '달': 87,
#  '여기': 88,
#  '항상': 89,
#  '마감': 90,
#  '확인': 91,
#  '왜': 92,
#  '일단': 93,
#  '역시': 94,
#  '뭐': 95,
#  '재질': 96,
#  '최고': 97,
#  '기분': 98,
#  '감': 99,
#  '손': 100,
#  '후기': 101,
#  '줄': 102,
#  '시간': 103,
#  '때문': 104,
#  '약간': 105,
#  '이건': 106,
#  '판매': 107,
#  '분': 108,
#  '쓰기': 109,
#  '날': 110,
#  '매우': 111,
#  '알': 112,
#  '도': 113,
#  '착용': 114,
#  '앞': 115,
#  '굿': 116,
#  '하루': 117,
#  '품질': 118,
#  '중': 119,
#  '고정': 120,
#  '문제': 121,
#  '길이': 122,
#  '피부': 123,
#  '소리': 124,
#  '살짝': 125,
#  '먹기': 126,
#  '원래': 127,
#  '리뷰': 128,
#  '말': 129,
#  '최악': 130,
#  '점': 131,
#  '햇': 132,
#  '전혀': 133,
#  '머리': 134,
#  '처리': 135,
#  '뚜껑': 136,
#  '건': 137,
#  '나': 138,
#  '여름': 139,
#  '제대로': 140,
#  '추가': 141,
#  '신경': 142,
#  '늘': 143,
#  '임': 144,
#  '사서': 145,
#  '걱정': 146,
#  '연락': 147,
#  '자꾸': 148,
#  '사람': 149,
#  '케이스': 150,
#  '세탁': 151,
#  '잘못': 152,
#  '먼지': 153,
#  '달라': 154,
#  '설명': 155,
#  '도착': 156,
#  '데': 157,
#  '애': 158,
#  '함': 159,
#  '거의': 160,
#  '금방': 161,
#  '자주': 162,
#  '끈': 163,
#  '여': 164,
#  '재': 165,
#  '구멍': 166,
#  '이상': 167,
#  '색깔': 168,
#  '커서': 169,
#  '구': 170,
#  '통': 171,
#  '충전': 172,
#  '살': 173,
#  '게': 174,
#  '기대': 175,
#  '커버': 176,
#  '안나': 177,
#  '지금': 178,
#  '다리': 179,
#  '빨': 180,
#  '시': 181,
#  '질': 182,
#  '그': 183,
#  '고민': 184,
#  '다만': 185,
#  '참고': 186,
#  '면': 187,
#  '제일': 188,
#  '환불': 189,
#  '입': 190,
#  '막': 191,
#  '두번째': 192,
#  '듭니': 193,
#  '전화': 194,
#  '일주일': 195,
#  '화면': 196,
#  '모두': 197,
#  '절대': 198,
#  '정리': 199,
#  '그대로': 200,
#  '음': 201,
#  '보': 202,
#  '작고': 203,
#  '자체': 204,
#  '배송비': 205,
#  '의사': 206,
#  '유통': 207,
#  '양': 208,
#  '엄마': 209,
#  '티': 210,
#  '기한': 211,
#  '바닥': 212,
#  '의자': 213,
#  '접착': 214,
#  '비닐': 215,
#  '발': 216,
#  '이용': 217,
#  '쪽': 218,
#  '위': 219,
#  '품': 220,
#  '눈': 221,
#  '나사': 222,
#  '문의': 223,
#  '가방': 224,
#  '팩': 225,
#  '등': 226,
#  '힘': 227,
#  '바람': 228,
#  '가지': 229,
#  '모양': 230,
#  '사': 231,
#  '바지': 232,
#  '크게': 233,
#  '덜': 234,
#  '고기': 235,
#  '꼭': 236,
#  '차이': 237,
#  '끝': 238,
#  '기존': 239,
#  '오늘': 240,
#  '기사': 241,
#  '퀄리티': 242,
#  '물이': 243,
#  '구성': 244,
#  '이불': 245,
#  '몇번': 246,
#  '얼굴': 247,
#  '친구': 248,
#  '습': 249,
#  '배': 250,
#  '엉망': 251,
#  '무게': 252,
#  '뭔가': 253,
#  '고장': 254,
#  '운동': 255,
#  '블랙': 256,
#  '산': 257,
#  '손잡이': 258,
#  '소재': 259,
#  '밑': 260,
#  '사은': 261,
#  '플라스틱': 262,
#  '애기': 263,
#  '뒤': 264,
#  '중간': 265,
#  '매번': 266,
#  '해도': 267,
#  '일': 268,
#  '자마자': 269,
#  '서비스': 270,
#  '연결': 271,
#  '후회': 272,
#  '차': 273,
#  '좀더': 274,
#  '보관': 275,
#  '두께': 276,
#  '키': 277,
#  '용량': 278,
#  '이제': 279,
#  '한쪽': 280,
#  '거리': 281,
#  '선택': 282,
#  '사지': 283,
#  '고무': 284,
#  '목': 285,
#  '번창': 286,
#  '장': 287,
#  '떡': 288,
#  '지퍼': 289,
#  '원단': 290,
#  '정품': 291,
#  '은': 292,
#  '일반': 293,
#  '별': 294,
#  '조절': 295,
#  '나무': 296,
#  '편이': 297,
#  '가루': 298,
#  '무': 299,
#  '로': 300,
#  '직접': 301,
#  '마리': 302,
#  '김치': 303,
#  '쿠션': 304,
#  '테이프': 305,
#  '기능': 306,
#  '수납': 307,
#  '실': 308,
#  '가요': 309,
#  '보통': 310,
#  '자국': 311,
#  '이유': 312,
#  '전체': 313,
#  '미리': 314,
#  '벌써': 315,
#  '너': 316,
#  '색도': 317,
#  '내': 318,
#  '냉동': 319,
#  '검수': 320,
#  '신발': 321,
#  '평': 322,
#  '담': 323,
#  '마트': 324,
#  '바': 325,
#  '기도': 326,
#  '예정': 327,
#  '요즘': 328,
#  '허리': 329,
#  '마스크': 330,
#  '스티커': 331,
#  '만': 332,
#  '기': 333,
#  '보기': 334,
#  '쓰레기': 335,
#  '광고': 336,
#  '겨울': 337,
#  '양도': 338,
#  '무난': 339,
#  '옆': 340,
#  '패드': 341,
#  '아들': 342,
#  '무엇': 343,
#  '영': 344,
#  '주': 345,
#  '남편': 346,
#  '우리': 347,
#  '루': 348,
#  '파손': 349,
#  '거품': 350,
#  '기름': 351,
#  '별루': 352,
#  '젤': 353,
#  '흰색': 354,
#  '움': 355,
#  '혼자': 356,
#  '그닥': 357,
#  '이즈': 358,
#  '저번': 359,
#  '예전': 360,
#  '제거': 361,
#  '고구마': 362,
#  '무슨': 363,
#  '화이트': 364,
#  '공간': 365,
#  '전이': 366,
#  '신랑': 367,
#  '인터넷': 368,
#  '높이': 369,
#  '봉': 370,
#  '작동': 371,
#  '편': 372,
#  '니': 373,
#  '매트': 374,
#  '부모님': 375,
#  '휘': 376,
#  '속': 377,
#  '컬러': 378,
#  '선': 379,
#  '비교': 380,
#  '밥': 381,
#  '글': 382,
#  '걸이': 383,
#  '세트': 384,
#  '업체': 385,
#  '요청': 386,
#  '그레이': 387,
#  '보이': 388,
#  '확정': 389,
#  '필름': 390,
#  '개월': 391,
#  '몇개': 392,
#  '밤': 393,
#  '평이': 394,
#  '색감': 395,
#  '핏': 396,
#  '감사': 397,
#  '개인': 398,
#  '여행': 399,
#  '자': 400,
#  '아침': 401,
#  '상자': 402,
#  '솜': 403,
#  '용도': 404,
#  '몸': 405,
#  '회사': 406,
#  '서랍': 407,
#  '교체': 408,
#  '흡수': 409,
#  '양념': 410,
#  '안쪽': 411,
#  '비지': 412,
#  '아예': 413,
#  '가슴': 414,
#  '볼': 415,
#  '핑크': 416,
#  '반': 417,
#  '건가': 418,
#  '기스': 419,
#  '성능': 420,
#  '고급': 421,
#  '대충': 422,
#  '겉': 423,
#  '당황': 424,
#  '침대': 425,
#  '굿굿': 426,
#  '하니': 427,
#  '입맛': 428,
#  '온': 429,
#  '배달': 430,
#  '답변': 431,
#  '모서리': 432,
#  '누가': 433,
#  '한지': 434,
#  '실제': 435,
#  '팬티': 436,
#  '발송': 437,
#  '내용물': 438,
#  '이틀': 439,
#  '신청': 440,
#  '취소': 441,
#  '심해': 442,
#  '평소': 443,
#  '기본': 444,
#  '소음': 445,
#  '드네': 446,
#  '상': 447,
#  '폭': 448,
#  '우선': 449,
#  '살이': 450,
#  '고객': 451,
#  '유리': 452,
#  '매일': 453,
#  '부위': 454,
#  '사고': 455,
#  '가족': 456,
#  '옴': 457,
#  '컵': 458,
#  '양말': 459,
#  '세척': 460,
#  '종이': 461,
#  '붙이': 462,
#  '짐': 463,
#  '부착': 464,
#  '대박': 465,
#  '트러블': 466,
#  '지속': 467,
#  '려고': 468,
#  '뻑뻑': 469,
#  '문자': 470,
#  '얼마': 471,
#  '자극': 472,
#  '가장': 473,
#  '강아지': 474,
#  '단': 475,
#  '끼': 476,
#  '어깨': 477,
#  '고생': 478,
#  '짱': 479,
#  '간식': 480,
#  '딸': 481,
#  '얼룩': 482,
#  '하자': 483,
#  '덕분': 484,
#  '종류': 485,
#  '실리콘': 486,
#  '지인': 487,
#  '털': 488,
#  '불': 489,
#  '가죽': 490,
#  '혹시': 491,
#  '흠': 492,
#  '장난': 493,
#  '스': 494,
#  '중국산': 495,
#  '강추': 496,
#  '저희': 497,
#  '작업': 498,
#  '위해': 499,
#  '나중': 500,
#  '값': 501,
#  '청소': 502,
#  '싸구려': 503,
#  '세번': 504,
#  '곰팡이': 505,
#  '봉지': 506,
#  '남': 507,
#  '실밥': 508,
#  '모기': 509,
#  '오': 510,
#  '건데': 511,
#  '그것': 512,
#  '두': 513,
#  '고리': 514,
#  '새': 515,
#  '차라리': 516,
#  '아가': 517,
#  '여자': 518,
#  '분리': 519,
#  '땐': 520,
#  '품절': 521,
#  '크림': 522,
#  '커피': 523,
#  '방': 524,
#  '채': 525,
#  '성분': 526,
#  '아이스팩': 527,
#  '샴푸': 528,
#  '어디': 529,
#  '전부': 530,
#  '부담': 531,
#  '받침': 532,
#  '아래': 533,
#  '바퀴': 534,
#  '방법': 535,
#  '땀': 536,
#  '무거워': 537,
#  '관리': 538,
#  '방지': 539,
#  '이해': 540,
#  '적극': 541,
#  '촉감': 542,
#  '고': 543,
#  '모자': 544,
#  '금액': 545,
#  '시작': 546,
#  '라인': 547,
#  '나름': 548,
#  '신축': 549,
#  '접': 550,
#  '기간': 551,
#  '경우': 552,
#  '보풀': 553,
#  '리': 554,
#  '코': 555,
#  '김': 556,
#  '상담': 557,
#  '빨래': 558,
#  '개봉': 559,
#  '밴드': 560,
#  '오히려': 561,
#  '며칠': 562,
#  '여기저기': 563,
#  '동안': 564,
#  '책상': 565,
#  '쫌': 566,
#  '바느질': 567,
#  '보지': 568,
#  '실물': 569,
#  '다행': 570,
#  '도움': 571,
#  '런가': 572,
#  '터치': 573,
#  '꽤': 574,
#  '테': 575,
#  '약': 576,
#  '문': 577,
#  '화장실': 578,
#  '나머지': 579,
#  '거치': 580,
#  '사료': 581,
#  '사실': 582,
#  '우유': 583,
#  '안해': 584,
#  '만해': 585,
#  '엉덩이': 586,
#  '버튼': 587,
#  '속도': 588,
#  '꽉': 589,
#  '두피': 590,
#  '음식': 591,
#  '준비': 592,
#  '겨우': 593,
#  '짜증': 594,
#  '용이': 595,
#  '판': 596,
#  '선반': 597,
#  '그거': 598,
#  '주변': 599,
#  '심플': 600,
#  '정사': 601,
#  '칼': 602,
#  '안보': 603,
#  '불편': 604,
#  '티나': 605,
#  '브랜드': 606,
#  '불만': 607,
#  '벽': 608,
#  '강': 609,
#  '실수': 610,
#  '휴대': 611,
#  '첨': 612,
#  '술': 613,
#  '주시': 614,
#  '해외': 615,
#  '남자': 616,
#  '유': 617,
#  '거울': 618,
#  '병': 619,
#  '껍질': 620,
#  '먼저': 621,
#  '첫': 622,
#  '방수': 623,
#  '만큼': 624,
#  '금': 625,
#  '배터리': 626,
#  '소스': 627,
#  '용기': 628,
#  '박음질': 629,
#  '보호': 630,
#  '도안': 631,
#  '지난번': 632,
#  '본드': 633,
#  '타': 634,
#  '치수': 635,
#  '및': 636,
#  '오징어': 637,
#  '수준': 638,
#  '대신': 639,
#  '귀': 640,
#  '빛': 641,
#  '신고': 642,
#  '트': 643,
#  '난리': 644,
#  '대가': 645,
#  '날짜': 646,
#  '인지': 647,
#  '캠핑': 648,
#  '코팅': 649,
#  '남아': 650,
#  '무료': 651,
#  '벌레': 652,
#  '질도': 653,
#  '손톱': 654,
#  '고해': 655,
#  '화장': 656,
#  '인식': 657,
#  '응대': 658,
#  '다해': 659,
#  '볼트': 660,
#  '다이어트': 661,
#  '워낙': 662,
#  '식': 663,
#  '확': 664,
#  '살걸': 665,
#  '얼음': 666,
#  '개중': 667,
#  '그게': 668,
#  '중이': 669,
#  '밖': 670,
#  '저녁': 671,
#  '속옷': 672,
#  '는걸': 673,
#  '베개': 674,
#  '일회용': 675,
#  '삿는데': 676,
#  '발라': 677,
#  '군데': 678,
#  '마무리': 679,
#  '를': 680,
#  '핸드폰': 681,
#  '라면': 682,
#  '언제': 683,
#  '날씨': 684,
#  '사이': 685,
#  '새우': 686,
#  '세': 687,
#  '네': 688,
#  '단점': 689,
#  '열': 690,
#  '베란다': 691,
#  '사면': 692,
#  '검색': 693,
#  '머': 694,
#  '답': 695,
#  '자석': 696,
#  '정': 697,
#  '꽃': 698,
#  '안심': 699,
#  '냉장고': 700,
#  '링': 701,
#  '신분': 702,
#  '스크래치': 703,
#  '거실': 704,
#  '아이보리': 705,
#  '물티슈': 706,
#  '어제': 707,
#  '판이': 708,
#  '한참': 709,
#  '시계': 710,
#  '폰': 711,
#  '스타일': 712,
#  '검정': 713,
#  '호': 714,
#  '뿌리': 715,
#  '실용': 716,
#  '활용': 717,
#  '사무실': 718,
#  '다이소': 719,
#  '깜짝': 720,
#  '주말': 721,
#  '코로나': 722,
#  '다가': 723,
#  '단맛': 724,
#  '가운데': 725,
#  '센터': 726,
#  '여유': 727,
#  '개선': 728,
#  '아쉬움': 729,
#  '저렴': 730,
#  '압축': 731,
#  '어머니': 732,
#  '표시': 733,
#  '해주시': 734,
#  '커튼': 735,
#  '사이트': 736,
#  '상한': 737,
#  '양쪽': 738,
#  '물질': 739,
#  '칫솔': 740,
#  '흠집': 741,
#  '수가': 742,
#  '필요': 743,
#  '가구': 744,
#  '작년': 745,
#  '누락': 746,
#  '싸이': 747,
#  '물품': 748,
#  '주머니': 749,
#  '손가락': 750,
#  '포': 751,
#  '지도': 752,
#  '얼마나': 753,
#  '된거': 754,
#  '차량': 755,
#  '안경': 756,
#  '가끔': 757,
#  '재고': 758,
#  '적': 759,
#  '이유식': 760,
#  '피': 761,
#  '모': 762,
#  '사기': 763,
#  '닭': 764,
#  '건강': 765,
#  '더니': 766,
#  '요리': 767,
#  '왓': 768,
#  '외출': 769,
#  '과정': 770,
#  '결제': 771,
#  '실패': 772,
#  '이전': 773,
#  '할인': 774,
#  '불량품': 775,
#  '장난감': 776,
#  '발림': 777,
#  '검은색': 778,
#  '샘플': 779,
#  '케이블': 780,
#  '만원': 781,
#  '국물': 782,
#  '액정': 783,
#  '망': 784,
#  '그림': 785,
#  '타입': 786,
#  '삿': 787,
#  '테이블': 788,
#  '펜': 789,
#  '봄': 790,
#  '손질': 791,
#  '머리카락': 792,
#  '지지': 793,
#  '수고': 794,
#  '일부러': 795,
#  '포기': 796,
#  '핀': 797,
#  '장갑': 798,
#  '분위기': 799,
#  '양면': 800,
#  '안내': 801,
#  '허벅지': 802,
#  '이나': 803,
#  '천이': 804,
#  '기저귀': 805,
#  '블루': 806,
#  '어이': 807,
#  '완료': 808,
#  '회색': 809,
#  '매장': 810,
#  '차단': 811,
#  '상처': 812,
#  '불만족': 813,
#  '프로': 814,
#  '심': 815,
#  '둘': 816,
#  '부품': 817,
#  '상세': 818,
#  '여러가지': 819,
#  '동생': 820,
#  '살껄': 821,
#  '쏙': 822,
#  '재료': 823,
#  '염색': 824,
#  '골드': 825,
#  '제작': 826,
#  '건전지': 827,
#  '인': 828,
#  '모델': 829,
#  '시트': 830,
#  '년': 831,
#  '에어': 832,
#  '현상': 833,
#  '라지': 834,
#  '단계': 835,
#  '캡': 836,
#  '옵션': 837,
#  '포인트': 838,
#  '드': 839,
#  '온도': 840,
#  '애용': 841,
#  '결': 842,
#  '터': 843,
#  '어른': 844,
#  '아빠': 845,
#  '인테리어': 846,
#  '거기': 847,
#  '몇': 848,
#  '수분': 849,
#  '검정색': 850,
#  '순간': 851,
#  '욕실': 852,
#  '봉투': 853,
#  '조리': 854,
#  '처럼': 855,
#  '청': 856,
#  '건조': 857,
#  '유심': 858,
#  '어찌': 859,
#  '휴지': 860,
#  '정상': 861,
#  '개별': 862,
#  '마': 863,
#  '자리': 864,
#  '조카': 865,
#  '워': 866,
#  '봣': 867,
#  '로션': 868,
#  '입구': 869,
#  '베이지': 870,
#  '일이': 871,
#  '야채': 872,
#  '예상': 873,
#  '위치': 874,
#  '상판': 875,
#  '무지': 876,
#  '타이': 877,
#  '감자': 878,
#  '투명': 879,
#  '지연': 880,
#  '스킨': 881,
#  '필터': 882,
#  '중국': 883,
#  '뻔': 884,
#  '충전기': 885,
#  '통화': 886,
#  '포함': 887,
#  '외': 888,
#  '식탁': 889,
#  '카드': 890,
#  '성도': 891,
#  '려': 892,
#  '화질': 893,
#  '빨대': 894,
#  '디': 895,
#  '착': 896,
#  '무늬': 897,
#  '팔': 898,
#  '달이': 899,
#  '사장': 900,
#  '기장': 901,
#  '갑자기': 902,
#  '중고': 903,
#  '위생': 904,
#  '표면': 905,
#  '생일': 906,
#  '겹': 907,
#  '브라': 908,
#  '심지어': 909,
#  '달달': 910,
#  '딸아이': 911,
#  '쌀': 912,
#  '만족도': 913,
#  '모래': 914,
#  '내용': 915,
#  '분사': 916,
#  '난': 917,
#  '미니': 918,
#  '이하': 919,
#  '이구': 920,
#  '물기': 921,
#  '과일': 922,
#  '정력': 923,
#  '연어': 924,
#  '진': 925,
#  '작': 926,
#  '질감': 927,
#  '네이버': 928,
#  '손목': 929,
#  '차지': 930,
#  '유지': 931,
#  '고양이': 932,
#  '치약': 933,
#  '한장': 934,
#  '뿐': 935,
#  '그릇': 936,
#  '원목': 937,
#  '첨부': 938,
#  '땜': 939,
#  '수도': 940,
#  '거부': 941,
#  '테두리': 942,
#  '처': 943,
#  '애가': 944,
#  '무조건': 945,
#  '사과': 946,
#  '게임': 947,
#  '용감': 948,
#  '과': 949,
#  '보습': 950,
#  '필수': 951,
#  '수평': 952,
#  '서도': 953,
#  '부탁': 954,
#  '오지': 955,
#  '신선도': 956,
#  '풀': 957,
#  '신어': 958,
#  '어': 959,
#  '진심': 960,
#  '맘에듭니': 961,
#  '자동': 962,
#  '막상': 963,
#  '페인트': 964,
#  '당일': 965,
#  '이름': 966,
#  '주일': 967,
#  '잔': 968,
#  '자전거': 969,
#  '레몬': 970,
#  '여러': 971,
#  '덕': 972,
#  '명': 973,
#  '주의': 974,
#  '향기': 975,
#  '과자': 976,
#  '반찬': 977,
#  '달도': 978,
#  '젠': 979,
#  '지고': 980,
#  '프레임': 981,
#  '틀': 982,
#  '주름': 983,
#  '고무줄': 984,
#  '일리': 985,
#  '인쇄': 986,
#  '불가': 987,
#  '완성': 988,
#  '각': 989,
#  '국산': 990,
#  '각질': 991,
#  '화가': 992,
#  '칸': 993,
#  '벌': 994,
#  '해먹': 995,
#  '브라운': 996,
#  '아무': 997,
#  '감안': 998,
#  '초': 999,
#  '생': 1000,
#  ...}

# %%
X = tokenizer.texts_to_sequences(tokenized_df['reviews'])
X[:10]
# Out:
# [[116],
#  [77, 251, 38, 67, 260, 1035, 129],
#  [30, 232, 23, 16, 11, 2, 6, 465, 567, 28, 73, 44, 97],
#  [55, 38, 1993, 19, 424, 63, 1, 746, 91, 25, 63, 55, 1967, 110, 1, 41, 8],
#  [1457, 57, 340, 258, 18, 38, 1387, 3],
#  [1020, 12, 37, 649, 334, 716, 8, 26, 14],
#  [9, 1, 88, 406, 194, 147, 108, 75, 50],
#  [122, 9, 25, 14],
#  [60, 12, 178, 177],
#  [672, 606, 904, 436, 59, 549, 293, 144, 358, 12, 12, 129]]

# %%
X = pad_sequences(X, maxlen=MAX_WORD_LENGTH, padding='post')
X[:10]
# Out:
# array([[ 116,    0,    0,    0,    0,    0,    0,    0,    0],
#        [  77,  251,   38,   67,  260, 1035,  129,    0,    0],
#        [  11,    2,    6,  465,  567,   28,   73,   44,   97],
#        [  91,   25,   63,   55, 1967,  110,    1,   41,    8],
#        [1457,   57,  340,  258,   18,   38, 1387,    3,    0],
#        [1020,   12,   37,  649,  334,  716,    8,   26,   14],
#        [   9,    1,   88,  406,  194,  147,  108,   75,   50],
#        [ 122,    9,   25,   14,    0,    0,    0,    0,    0],
#        [  60,   12,  178,  177,    0,    0,    0,    0,    0],
#        [ 436,   59,  549,  293,  144,  358,   12,   12,  129]],
#       dtype=int32)

# %%
X.shape
# Out:
# (165961, 9)

# %%
y = tokenized_df['ratings'].values
y
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
y.shape
# Out:
# (165961,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=826)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (149364, 9) (149364,)
# (16597, 9) (16597,)

# %% [markdown]
# ## 6.RNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Embedding
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
model = Sequential()
model.add(Embedding(MAX_NUM_WORD, 16, input_length=MAX_WORD_LENGTH))
model.add(SimpleRNN(32, dropout=0.1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 9, 16)             32000
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 32)                1568
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.1,
    callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=3)]
)
# Out:
# Epoch 1/10
# 1051/1051 [==============================] - 18s 13ms/step - loss: 0.4806 - accuracy: 0.7621 - val_loss: 0.4497 - val_accuracy: 0.7861
# Epoch 2/10
# 1051/1051 [==============================] - 13s 13ms/step - loss: 0.4427 - accuracy: 0.7901 - val_loss: 0.4524 - val_accuracy: 0.7871
# Epoch 3/10
# 1051/1051 [==============================] - 13s 13ms/step - loss: 0.4337 - accuracy: 0.7952 - val_loss: 0.4510 - val_accuracy: 0.7853
# Epoch 4/10
# 1051/1051 [==============================] - 14s 13ms/step - loss: 0.4256 - accuracy: 0.8000 - val_loss: 0.4551 - val_accuracy: 0.7836

# %%
model.evaluate(X_test, y_test)
# Out:
# 519/519 [==============================] - 1s 3ms/step - loss: 0.4612 - accuracy: 0.7783
# [0.4612373113632202, 0.7782731652259827]

# %%
plt.figure(figsize=(8, 8))
plt.plot(history.epoch, history.history['loss'], label='loss')
plt.plot(history.epoch, history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(history.epoch, history.history['accuracy'], label='accuracy')
plt.plot(history.epoch, history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## 7.LSTM

# %%
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(Embedding(MAX_NUM_WORD, 16, input_length=MAX_WORD_LENGTH))
model.add(LSTM(32, dropout=0.1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 9, 16)             32000
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                6272
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 38,305
# Trainable params: 38,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.1,
    callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=3)]
)
# Out:
# Epoch 1/20
# 1051/1051 [==============================] - 12s 5ms/step - loss: 0.4795 - accuracy: 0.7616 - val_loss: 0.4469 - val_accuracy: 0.7858
# Epoch 2/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4411 - accuracy: 0.7890 - val_loss: 0.4458 - val_accuracy: 0.7872
# Epoch 3/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4356 - accuracy: 0.7924 - val_loss: 0.4371 - val_accuracy: 0.7900
# Epoch 4/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4300 - accuracy: 0.7950 - val_loss: 0.4379 - val_accuracy: 0.7902
# Epoch 5/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4254 - accuracy: 0.7984 - val_loss: 0.4421 - val_accuracy: 0.7828
# Epoch 6/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4226 - accuracy: 0.8001 - val_loss: 0.4394 - val_accuracy: 0.7909

# %%
model.evaluate(X_test, y_test)
# Out:
# 519/519 [==============================] - 1s 2ms/step - loss: 0.4494 - accuracy: 0.7848
# [0.44941458106040955, 0.7847803831100464]

# %% [markdown]
# ## 7.GRU

# %%
from tensorflow.keras.layers import GRU

# %%
model = Sequential()
model.add(Embedding(MAX_NUM_WORD, 16, input_length=MAX_WORD_LENGTH))
model.add(GRU(32, dropout=0.1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 9, 16)             32000
# _________________________________________________________________
# gru (GRU)                    (None, 32)                4800
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 36,833
# Trainable params: 36,833
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.1,
    callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=3)]
)
# Out:
# Epoch 1/20
# 1051/1051 [==============================] - 8s 6ms/step - loss: 0.4769 - accuracy: 0.7608 - val_loss: 0.4485 - val_accuracy: 0.7792
# Epoch 2/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4415 - accuracy: 0.7892 - val_loss: 0.4421 - val_accuracy: 0.7865
# Epoch 3/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4372 - accuracy: 0.7914 - val_loss: 0.4399 - val_accuracy: 0.7891
# Epoch 4/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4326 - accuracy: 0.7934 - val_loss: 0.4389 - val_accuracy: 0.7880
# Epoch 5/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4274 - accuracy: 0.7966 - val_loss: 0.4371 - val_accuracy: 0.7911
# Epoch 6/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4238 - accuracy: 0.7985 - val_loss: 0.4366 - val_accuracy: 0.7929
# Epoch 7/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4206 - accuracy: 0.7997 - val_loss: 0.4386 - val_accuracy: 0.7945
# Epoch 8/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4177 - accuracy: 0.8013 - val_loss: 0.4400 - val_accuracy: 0.7890
# Epoch 9/20
# 1051/1051 [==============================] - 5s 5ms/step - loss: 0.4136 - accuracy: 0.8036 - val_loss: 0.4408 - val_accuracy: 0.7940

# %%
model.evaluate(X_test, y_test)
# Out:
# 519/519 [==============================] - 1s 2ms/step - loss: 0.4509 - accuracy: 0.7868
# [0.45093855261802673, 0.7867686748504639]

# %% [markdown]
# ㅠㅠ paramter 값들을 바꾸면 성능이 좋아질지도?!

# %% [markdown]
# ## 8.형태소로 토큰화

# %% [markdown]
# 형태소란?
#
# : 의미를 가지는 요소로서는 더 이상 분석할 수 없는 가장 작은 말의 단위

# %%
stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게']

# %%
okt = Okt()
tokenized_morph = []

for review in tqdm(naver_review_df['reviews']):
    tokenized = okt.morphs(review, stem=True)
    tokenized = [data for data in tokenized if data not in stopwords]
    tokenized_morph.append(" ".join(tokenized))
# Out:
# 100%|██████████| 199898/199898 [11:40<00:00, 285.35it/s]

# %%
with open('/content/gdrive/MyDrive/Ulsan_univ/dohee/shared/배포자료_리뷰분류/data/naver_morph.pkl', 'rb') as f:
    tokenized_morph = pickle.load(f)

# %%
tokenized_df = pd.DataFrame(data={'reviews': tokenized_morph, 'ratings': naver_review_df['ratings']})
tokenized_df.reset_index(drop=True, inplace=True)
tokenized_df
# Out:
#                                                   reviews  ratings
# 0                                                배공 빠르다 굿        1
# 1                            택배 엉망 이네 용 저희 집 밑 층 말 없이 놔두다        0
# 2       아주 좋다 바지 정말 좋다 2 개 더 구매 하다 가격 대박 이다 . 바느질 조금 엉...        1
# 3       선물 용 으로 빨리 받다 전달 하다 하다 상품 이다 머그컵 만 오다 당황 하다 . ...        0
# 4                       민트 색상 예쁘다 . 옆 손잡이 거 용 도로 사용 되다 ㅎㅎ        1
# ...                                                   ...      ...
# 199893                                 장마 라 그 런가 !!! 달 않다        0
# 199894  다이슨 케이스 구매 하다 다이슨 슈퍼소닉 드라이기 케이스 구매 하다 가격 괜찮다 배...        1
# 199895                        로드샾 에서 살다 세배 저렴하다 ㅜㅜ 자주 용하다        1
# 199896                                 넘다 이쁘다 쎄다 되다 보이다 ~        1
# 199897       아직 사용 해보다 않다 다른 제품 써다 본적 없다 자다 모르다 ㅎㅎ 배송 빨르다        1
#
# [199898 rows x 2 columns]

# %% [markdown]
# ### 중복제거

# %%
tokenized_df[tokenized_df.duplicated()]
# Out:
#                       reviews  ratings
# 3926                배송 빨르다 좋다        1
# 4661                   비추다 이다        0
# 5810           한진택배 배송 너무 느리다        0
# 7524                   배송 빠르다        0
# 10074             배송 빠르다 감사하다        1
# ...                       ...      ...
# 198731   저희 집 창문 이랑은 사이즈 안 맞다        0
# 198767             배송 빨 라서 좋다        1
# 198865  가슴 부위 너무 파이다 길이 너무 짧다        0
# 199037                    버리다        0
# 199125             냄새 많이 나다 .        0
#
# [872 rows x 2 columns]

# %%
tokenized_df[tokenized_df.duplicated(subset=['reviews'])]
# Out:
#                       reviews  ratings
# 3926                배송 빨르다 좋다        1
# 4661                   비추다 이다        0
# 5810           한진택배 배송 너무 느리다        0
# 7524                   배송 빠르다        0
# 10074             배송 빠르다 감사하다        1
# ...                       ...      ...
# 198767             배송 빨 라서 좋다        1
# 198865  가슴 부위 너무 파이다 길이 너무 짧다        0
# 199037                    버리다        0
# 199125             냄새 많이 나다 .        0
# 199750          깔끔하다 정리 되다 좋다        0
#
# [1004 rows x 2 columns]

# %%
tokenized_df.drop_duplicates(subset=['reviews'], inplace=True, ignore_index=True)
tokenized_df
# Out:
#                                                   reviews  ratings
# 0                                                배공 빠르다 굿        1
# 1                            택배 엉망 이네 용 저희 집 밑 층 말 없이 놔두다        0
# 2       아주 좋다 바지 정말 좋다 2 개 더 구매 하다 가격 대박 이다 . 바느질 조금 엉...        1
# 3       선물 용 으로 빨리 받다 전달 하다 하다 상품 이다 머그컵 만 오다 당황 하다 . ...        0
# 4                       민트 색상 예쁘다 . 옆 손잡이 거 용 도로 사용 되다 ㅎㅎ        1
# ...                                                   ...      ...
# 198889                                 장마 라 그 런가 !!! 달 않다        0
# 198890  다이슨 케이스 구매 하다 다이슨 슈퍼소닉 드라이기 케이스 구매 하다 가격 괜찮다 배...        1
# 198891                        로드샾 에서 살다 세배 저렴하다 ㅜㅜ 자주 용하다        1
# 198892                                 넘다 이쁘다 쎄다 되다 보이다 ~        1
# 198893       아직 사용 해보다 않다 다른 제품 써다 본적 없다 자다 모르다 ㅎㅎ 배송 빨르다        1
#
# [198894 rows x 2 columns]

# %%
tokenized_df[tokenized_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [reviews, ratings]
# Index: []

# %% [markdown]
# ### 비어있는 review 제거

# %%
tokenized_df.query('reviews == ""')
# Out:
# Empty DataFrame
# Columns: [reviews, ratings]
# Index: []

# %%
empty_index = list(tokenized_df.query('reviews == ""').index)
tokenized_df.drop(empty_index, inplace=True)
tokenized_df.reset_index(drop=True, inplace=True)
tokenized_df
# Out:
#                                                   reviews  ratings
# 0                                                배공 빠르다 굿        1
# 1                            택배 엉망 이네 용 저희 집 밑 층 말 없이 놔두다        0
# 2       아주 좋다 바지 정말 좋다 2 개 더 구매 하다 가격 대박 이다 . 바느질 조금 엉...        1
# 3       선물 용 으로 빨리 받다 전달 하다 하다 상품 이다 머그컵 만 오다 당황 하다 . ...        0
# 4                       민트 색상 예쁘다 . 옆 손잡이 거 용 도로 사용 되다 ㅎㅎ        1
# ...                                                   ...      ...
# 198889                                 장마 라 그 런가 !!! 달 않다        0
# 198890  다이슨 케이스 구매 하다 다이슨 슈퍼소닉 드라이기 케이스 구매 하다 가격 괜찮다 배...        1
# 198891                        로드샾 에서 살다 세배 저렴하다 ㅜㅜ 자주 용하다        1
# 198892                                 넘다 이쁘다 쎄다 되다 보이다 ~        1
# 198893       아직 사용 해보다 않다 다른 제품 써다 본적 없다 자다 모르다 ㅎㅎ 배송 빨르다        1
#
# [198894 rows x 2 columns]

# %%
tokenized_df['reviews'].apply(lambda x: len(x.split())).value_counts().sort_index().plot(kind='bar', figsize=(12, 6));
tokenized_df['reviews'].apply(lambda x: len(x.split())).describe()
# Out:
# count    198894.000000
# mean         13.674435
# std           9.982757
# min           1.000000
# 25%           6.000000
# 50%          10.000000
# 75%          19.000000
# max          77.000000
# Name: reviews, dtype: float64

# %% [markdown]
# ## 5.단어 정수 인코딩

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
MAX_NUM_WORD = 2000
MAX_WORD_LENGTH = 19

# %%
tokenizer = Tokenizer(MAX_NUM_WORD)
tokenizer.fit_on_texts(tokenized_df['reviews'])
len(tokenizer.word_index)
# Out:
# 45160

# %%
X = tokenizer.texts_to_sequences(tokenized_df['reviews'])
X[:5]
# Out:
# [[27, 261],
#  [201, 524, 150, 115, 554, 181, 542, 1720, 314, 161, 1478],
#  [83,
#   2,
#   497,
#   67,
#   2,
#   99,
#   48,
#   36,
#   14,
#   1,
#   28,
#   867,
#   16,
#   1041,
#   91,
#   727,
#   1125,
#   343,
#   53,
#   173,
#   122,
#   238,
#   169],
#  [130,
#   115,
#   23,
#   280,
#   31,
#   1,
#   1,
#   60,
#   16,
#   41,
#   18,
#   819,
#   1,
#   1018,
#   178,
#   121,
#   1,
#   4,
#   1311,
#   89,
#   235,
#   10,
#   35,
#   178,
#   130,
#   1,
#   271,
#   1458,
#   284,
#   4,
#   212,
#   157,
#   249,
#   126,
#   29,
#   1,
#   7,
#   97],
#  [143, 76, 670, 532, 59, 115, 19, 20, 81]]

# %%
X = pad_sequences(X, maxlen=MAX_WORD_LENGTH, padding='post')
X
# Out:
# array([[  27,  261,    0, ...,    0,    0,    0],
#        [ 201,  524,  150, ...,    0,    0,    0],
#        [   2,   99,   48, ...,  122,  238,  169],
#        ...,
#        [  49,  249,   63, ...,    0,    0,    0],
#        [  65,   64, 1595, ...,    0,    0,    0],
#        [ 104,   19,  151, ...,    0,    0,    0]], dtype=int32)

# %%
X.shape
# Out:
# (198894, 19)

# %%
y = tokenized_df['ratings'].values
y
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=826)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (179004, 19) (179004,)
# (19890, 19) (19890,)

# %% [markdown]
# ## 9.형태소토큰화_RNN

# %%
model = Sequential()
model.add(Embedding(MAX_NUM_WORD, 16, input_length=MAX_WORD_LENGTH))
model.add(SimpleRNN(32, dropout=0.1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 19, 16)            32000
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 32)                1568
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.1,
    callbacks=[EarlyStoppingas(monitor='val_loss', min_delta=0.0001, patience=3)]
)
# Out:
# Epoch 1/10
# 1259/1259 [==============================] - 33s 25ms/step - loss: 0.3270 - accuracy: 0.8666 - val_loss: 0.2839 - val_accuracy: 0.8886
# Epoch 2/10
# 1259/1259 [==============================] - 30s 24ms/step - loss: 0.2806 - accuracy: 0.8913 - val_loss: 0.2766 - val_accuracy: 0.8934
# Epoch 3/10
# 1259/1259 [==============================] - 30s 24ms/step - loss: 0.2702 - accuracy: 0.8948 - val_loss: 0.2726 - val_accuracy: 0.8925
# Epoch 4/10
# 1259/1259 [==============================] - 30s 24ms/step - loss: 0.2623 - accuracy: 0.8980 - val_loss: 0.2755 - val_accuracy: 0.8926
# Epoch 5/10
# 1259/1259 [==============================] - 29s 23ms/step - loss: 0.2561 - accuracy: 0.9001 - val_loss: 0.2795 - val_accuracy: 0.8882
# Epoch 6/10
# 1259/1259 [==============================] - 31s 24ms/step - loss: 0.2505 - accuracy: 0.9026 - val_loss: 0.2737 - val_accuracy: 0.8931

# %%
model.evaluate(X_test, y_test)
# Out:
# 622/622 [==============================] - 2s 3ms/step - loss: 0.2693 - accuracy: 0.8972
# [0.26930221915245056, 0.8971844911575317]

# %%
plt.figure(figsize=(8, 8))
plt.plot(history.epoch, history.history['loss'], label='loss')
plt.plot(history.epoch, history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(history.epoch, history.history['accuracy'], label='accuracy')
plt.plot(history.epoch, history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## 10.모델 저장하기

# %%
# path = '/content/gdrive/MyDrive/Ulsan_univ/model/'
# model.save(path+'RNN_morph_batch16_epoch10.h5')

# %% [markdown]
# ## 11.질문!
